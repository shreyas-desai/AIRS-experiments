# %%
import pandas as pd

# %%
data = pd.read_pickle("../data/data/data/gdelt/gdelt.pkl")

# %%
data
# Out:
# {'num_entity': 2279,
#  'num_rel': 20,
#  'data': [(72,
#    26,
#    3,
#    0.0,
#    'event headline:Biden to Speak with Zelenskiy, Says He Warned Putin on Ukraine; event type:CONSULT; event time:2022-01-01; subject name:CANADA; object name:ITALY.'),
#   (5,
#    0,
#    5,
#    0.0,
#    'event headline:8 year old girl killed by driver who fled in; event type:ENGAGE IN MATERIAL COOPERATION; event time:2022-01-01; subject name:POLICE OFFICER; object name:UNITED STATES.'),
#   (0,
#    47,
#    4,
#    0.0,
#    'event headline:So Close! Grand Rapids Eatery Ranked No; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:UNITED STATES; object name:SPANISH.'),
#   (0,
#    10,
#    0,
#    0.0,
#    'event headline:prairie cash wheat bids down despite cold weather russian tensions; event type:MAKE STATEMENT; event time:2022-01-01; subject name:MINNEAPOLIS; object name:CANADA.'),
#   (0,
#    24,
#    0,
#    0.0,
#    'event headline:Prison Sentence Stayed For Man Who Sexually Assaulted Girl; event type:MAKE STATEMENT; event time:2022-01-01; subject name:UNITED STATES; object name:CRIMINAL.'),
#   (0,
#    11,
#    0,
#    0.0,
#    'event headline:Betty White Dies at 99; event type:MAKE STATEMENT; event time:2022-01-01; subject name:UNITED STATES; object name:PUBLICATION.'),
#   (36,
#    0,
#    10,
#    0.0,
#    'event headline:__iracle_ that no loss of life in Colorado urban wildfire -Governor; event type:DISAPPROVE; event time:2022-01-01; subject name:REUTERS; object name:DENVER.'),
#   (0,
#    6,
#    0,
#    0.0,
#    'event headline:Massachusetts denies teacher union__ request to keep schools closed for COVID-19 testing; event type:MAKE STATEMENT; event time:2022-01-01; subject name:MASSACHUSETTS; object name:SCHOOL.'),
#   (0,
#    10,
#    1,
#    0.0,
#    'event headline:Grey-Bruce sees 82 more COVID cases, eighth in hospital Friday; event type:APPEAL; event time:2022-01-01; subject name:UNITED STATES; object name:ONTARIO.'),
#   (0,
#    5,
#    4,
#    0.0,
#    'event headline:__t__ been a crazy year_: Local bars hope for New Years boost; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:INDIANA; object name:POLICE.'),
#   (51,
#    1,
#    1,
#    0.0,
#    'event headline:Comrade Joe Still Hampers Rescue of US Citizens & Residents in Afghanistan; event type:APPEAL; event time:2022-01-01; subject name:AFGHANISTAN; object name:EMBASSY.'),
#   (7,
#    519,
#    4,
#    0.0,
#    'event headline:China opens embassy in Nicaragua for 1st time since 1990; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:CHINA; object name:NICARAGUA.'),
#   (57,
#    2,
#    11,
#    0.0,
#    'event headline:News business sees low ratings without divisive politics of 2020; event type:REJECT; event time:2022-01-01; subject name:WARSAW; object name:COMPANIES.'),
#   (33,
#    23,
#    3,
#    0.0,
#    'event headline:NY celebrations in full swing at Expo 2020 as 12 countries enter 2022, with 180 more to come; event type:CONSULT; event time:2022-01-01; subject name:TIMOR; object name:JAPAN.'),
#   (565,
#    565,
#    6,
#    0.0,
#    'event headline:Baroness Amos is first black person appointed by Queen to prestigious order; event type:PROVIDE AID; event time:2022-01-01; subject name:TONY BLAIR; object name:TONY BLAIR.'),
#   (20,
#    141,
#    0,
#    0.0,
#    'event headline:US airlines grapple with omicron-related disruptions on last day of the year; event type:MAKE STATEMENT; event time:2022-01-01; subject name:EMPLOYEE; object name:CHEVRON.'),
#   (0,
#    2,
#    1,
#    0.0,
#    'event headline:Best car insurance in Louisiana in 2022; event type:APPEAL; event time:2022-01-01; subject name:LOUISIANA; object name:COMPANY.'),
#   (2,
#    382,
#    17,
#    0.0,
#    'event headline:former bt chairman jan du plessis knighted for services to telecoms; event type:ASSAULT; event time:2022-01-01; subject name:COMPANIES; object name:RIO TINTO.'),
#   (35,
#    1059,
#    18,
#    0.0,
#    'event headline:Global Antisemitism’s Top Ten; event type:FIGHT; event time:2022-01-01; subject name:ISRAEL; object name:UNITED KINGDOM.'),
#   (1,
#    7,
#    16,
#    0.0,
#    'event headline:Chinese officials promise groceries for lockdown residents; event type:COERCE; event time:2022-01-01; subject name:AUTHORITIES; object name:XIAN.'),
#   (2,
#    27,
#    15,
#    0.0,
#    'event headline:Wave of Canceled Flights From Omicron Closes Out 2021; event type:REDUCE RELATIONS; event time:2022-01-01; subject name:AIRLINE; object name:DELTA AIR LINES.'),
#   (2,
#    0,
#    18,
#    0.0,
#    'event headline:High-Profile Crimes of 2021; event type:FIGHT; event time:2022-01-01; subject name:BUSINESS; object name:DENVER.'),
#   (6,
#    365,
#    10,
#    0.0,
#    'event headline:Teenage friend of leprosy patients wins prize for life mission essay; event type:DISAPPROVE; event time:2022-01-01; subject name:STUDENT; object name:TOKYO.'),
#   (4,
#    1,
#    9,
#    0.0,
#    'event headline:Governor Stuns Louisiana with COVID Omicron News Announcement; event type:DEMAND; event time:2022-01-01; subject name:CITIZEN; object name:GOVERNOR.'),
#   (7,
#    61,
#    4,
#    0.0,
#    'event headline:flashback 2021 2929946; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:CHINESE; object name:TAIWANESE.'),
#   (5,
#    0,
#    1,
#    0.0,
#    'event headline:Seen Him? Statewide Alert Issued For Wanted New York Man; event type:APPEAL; event time:2022-01-01; subject name:POLICE; object name:UNITED STATES.'),
#   (24,
#    0,
#    16,
#    0.0,
#    'event headline:Two charged at RIDE spot checks this week by Grey Bruce OPP; event type:COERCE; event time:2022-01-01; subject name:CRIMINAL; object name:UNITED STATES.'),
#   (9,
#    3,
#    10,
#    0.0,
#    "event headline:Russia comments on Ukraine's energy problems; event type:DISAPPROVE; event time:2022-01-01; subject name:UKRAINE; object name:RUSSIA."),
#   (5,
#    17,
#    16,
#    0.0,
#    'event headline:Suspect in Shooting of Illinois Officers Arrested in Indiana; event type:COERCE; event time:2022-01-01; subject name:POLICE OFFICER; object name:MANCHESTER.'),
#   (5,
#    0,
#    16,
#    0.0,
#    'event headline:Suspect wanted in death of Bradley officer arrested in rural Indiana; another remains at-large; event type:COERCE; event time:2022-01-01; subject name:POLICE; object name:UNITED STATES.'),
#   (5,
#    3,
#    4,
#    0.0,
#    'event headline:You Could Face Two Years in Jail for Celebratory Gun Fire on New Year’s Eve in Acadiana [Video]; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:POLICE CHIEF; object name:RUSSIA.'),
#   (39,
#    25,
#    1,
#    0.0,
#    'event headline:Outlook, Office, Skype, Bing, Breaking News, and Latest Videos; event type:APPEAL; event time:2022-01-01; subject name:THE EUROPEAN UNION; object name:EUROPEAN.'),
#   (25,
#    39,
#    2,
#    0.0,
#    'event headline:Macron "optimistic" for 2022, warning upcoming "few difficult weeks"; event type:EXPRESS INTENT TO COOPERATE; event time:2022-01-01; subject name:EUROPEAN; object name:THE EUROPEAN UNION.'),
#   (32,
#    6,
#    0,
#    0.0,
#    'event headline:The Golden Girls’ star Betty White dead at 99; event type:MAKE STATEMENT; event time:2022-01-01; subject name:ACTOR; object name:PROFESSOR.'),
#   (32,
#    0,
#    0,
#    0.0,
#    'event headline:10 Famous Actors Who Lied To Get Movie And TV Roles; event type:MAKE STATEMENT; event time:2022-01-01; subject name:ACTOR; object name:UNITED STATES.'),
#   (15,
#    1,
#    15,
#    0.0,
#    'event headline:Asia looks to China-focused trade bloc for virus recovery; event type:REDUCE RELATIONS; event time:2022-01-01; subject name:MILITARY; object name:GOVERNMENT.'),
#   (23,
#    2,
#    0,
#    0.0,
#    'event headline:Wall clock that survived A-bomb keeps on ticking 77 years later; event type:MAKE STATEMENT; event time:2022-01-01; subject name:JAPAN; object name:INDUSTRY.'),
#   (26,
#    4,
#    4,
#    0.0,
#    'event headline:Italian president thanks citizens for sense of responsibility in New Year speech; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:ITALIAN; object name:CITIZEN.'),
#   (23,
#    2,
#    6,
#    0.0,
#    "event headline:BTS's Jimin trends worldwide with multiple entries as fans celebrate 'Promise' 3rd anniversary with animal adoptions, giveaways, café events, tree planting, and donations; event type:PROVIDE AID; event time:2022-01-01; subject name:JAPAN; object name:CORPORATION."),
#   (8,
#    0,
#    2,
#    0.0,
#    "event headline:Ghislaine Maxwell's been convicted; event type:EXPRESS INTENT TO COOPERATE; event time:2022-01-01; subject name:DEFENSE ATTORNEY; object name:UNITED STATES."),
#   (1,
#    80,
#    18,
#    0.0,
#    'event headline:Eric Adams Is a Vaccinator! Just Another De Blasio; event type:FIGHT; event time:2022-01-01; subject name:MAYOR; object name:SCHOOL.'),
#   (219,
#    41,
#    10,
#    0.0,
#    'event headline:Iran Space Rocket Fails to Reach Orbit; event type:DISAPPROVE; event time:2022-01-01; subject name:IRAN; object name:TEHRAN.'),
#   (13,
#    0,
#    18,
#    0.0,
#    'event headline:Cabinet papers 2001: John Howard feels ‘no guilt’ over Tampa; event type:FIGHT; event time:2022-01-01; subject name:AUSTRALIAN; object name:TAMPA.'),
#   (11,
#    0,
#    7,
#    0.0,
#    'event headline:FDA reportedly close to authorizing third Pfizer shot for kids 12-15; US averaging record 300,000 daily reported cases: Live COVID updates; event type:YIELD; event time:2022-01-01; subject name:WEBSITE; object name:AMERICAN.'),
#   (11,
#    3,
#    4,
#    0.0,
#    'event headline:biden extends us support for international space station through 2030; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:NEWS AGENCY; object name:RUSSIA.'),
#   (54,
#    21,
#    0,
#    0.0,
#    'event headline:covid 19 cases skyrocketing more than 27 000 new l a infections; event type:MAKE STATEMENT; event time:2022-01-01; subject name:HEALTH OFFICIAL; object name:HOSPITAL.'),
#   (11,
#    0,
#    3,
#    0.0,
#    'event headline:Spry on her 95th birthday, Betty White offers some life advice; event type:CONSULT; event time:2022-01-01; subject name:TELEVISION; object name:UNITED STATES.'),
#   (1,
#    0,
#    7,
#    0.0,
#    'event headline:Firefighters Rescue Injured Woman From Minnesota Cave; event type:YIELD; event time:2022-01-01; subject name:FIRE DEPARTMENT; object name:MINNEAPOLIS.'),
#   (11,
#    0,
#    3,
#    0.0,
#    'event headline:Betty White, legendary TV actress and cultural icon, dies at 99; event type:CONSULT; event time:2022-01-01; subject name:TELEVISION; object name:UNITED STATES.'),
#   (27,
#    3,
#    1,
#    0.0,
#    'event headline:Netflix will be required to stream 20 state TV channels in Russia; event type:APPEAL; event time:2022-01-01; subject name:NETFLIX; object name:RUSSIA.'),
#   (6,
#    0,
#    3,
#    0.0,
#    'event headline:NY Gov Hochul Will Decide If you’re Essential; event type:CONSULT; event time:2022-01-01; subject name:PROFESSOR; object name:NEW YORK.'),
#   (17,
#    39,
#    0,
#    0.0,
#    'event headline:I’ll go further and faster to make Brexit a success, says Boris Johnson on anniversary; event type:MAKE STATEMENT; event time:2022-01-01; subject name:UNITED KINGDOM; object name:EUROPEAN UNION.'),
#   (13,
#    4,
#    3,
#    0.0,
#    'event headline:beached bluebottles; event type:CONSULT; event time:2022-01-01; subject name:AUSTRALIA; object name:TOURIST.'),
#   (48,
#    494,
#    3,
#    0.0,
#    'event headline:Biden to speak with Ukraine president as US warns against Russian invasion; event type:CONSULT; event time:2022-01-01; subject name:NATO; object name:JENS STOLTENBERG.'),
#   (0,
#    7,
#    0,
#    0.020833333333333332,
#    'event headline:RCEP set to boost regional, global growth; event type:MAKE STATEMENT; event time:2022-01-01; subject name:UNITED STATES; object name:CHINA.'),
#   (8,
#    12,
#    0,
#    0.020833333333333332,
#    'event headline:Chief Justice Roberts touts independence of federal courts as some lawmakers press for change; event type:MAKE STATEMENT; event time:2022-01-01; subject name:JUDGE; object name:CONGRESS.'),
#   (4,
#    97,
#    3,
#    0.020833333333333332,
#    'event headline:Press Ahead to a Promising Future; event type:CONSULT; event time:2022-01-01; subject name:ENGINEER; object name:PHILIPPINE.'),
#   (5,
#    30,
#    13,
#    0.020833333333333332,
#    'event headline:Durkan Leaves Behind a Mess After Four Rudderless Years; event type:PROTEST; event time:2022-01-01; subject name:POLICE; object name:PROTESTER.'),
#   (21,
#    0,
#    1,
#    0.020833333333333332,
#    'event headline:Morris named MCCH November Employee of the Month; event type:APPEAL; event time:2022-01-01; subject name:NURSE; object name:UNITED STATES.'),
#   (14,
#    704,
#    3,
#    0.020833333333333332,
#    'event headline:South Africans Bid Farewell to Tutu on Eve of His Funeral; event type:CONSULT; event time:2022-01-01; subject name:AFRICA; object name:ANGLICAN.'),
#   (10,
#    20,
#    1,
#    0.020833333333333332,
#    'event headline:Visitors restricted in B; event type:APPEAL; event time:2022-01-01; subject name:CANADA; object name:WORKER.'),
#   (14,
#    4,
#    5,
#    0.020833333333333332,
#    'event headline:Desmond Tutu: An inspiration for a broken nation _ DW _ 12; event type:ENGAGE IN MATERIAL COOPERATION; event time:2022-01-01; subject name:AFRICA; object name:TOURIST.'),
#   (4,
#    11,
#    0,
#    0.020833333333333332,
#    'event headline:guitar master rohn lawrence dies; event type:MAKE STATEMENT; event time:2022-01-01; subject name:COMMUNITY; object name:MEDIA.'),
#   (2,
#    20,
#    1,
#    0.020833333333333332,
#    'event headline:detail; event type:APPEAL; event time:2022-01-01; subject name:AIRLINE; object name:WORKER.'),
#   (1,
#    129,
#    4,
#    0.020833333333333332,
#    'event headline:King, Crown Prince greet Sudanese, Cuban and Slovak leaders; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:KING; object name:CUBA.'),
#   (27,
#    8,
#    9,
#    0.020833333333333332,
#    'event headline:2021 Year in Review: Noteworthy Precedent for Patent Litigators; event type:DEMAND; event time:2022-01-01; subject name:AMGEN INC; object name:DISTRICT COURT.'),
#   (0,
#    11,
#    18,
#    0.020833333333333332,
#    'event headline:Gunfire erupts as 65 shots fired on Philadelphia street packed with pedestrians; event type:FIGHT; event time:2022-01-01; subject name:PHILADELPHIA; object name:WEBSITE.'),
#   (0,
#    5,
#    18,
#    0.020833333333333332,
#    'event headline:Free ZTrip rides this holiday season; event type:FIGHT; event time:2022-01-01; subject name:UNITED STATES; object name:TROOPER.'),
#   (82,
#    34,
#    8,
#    0.020833333333333332,
#    'event headline:TV reporter cuts short live segment after discovering on-air that house is being burgled; event type:INVESTIGATE; event time:2022-01-01; subject name:ARGENTINIAN; object name:PUEBLA.'),
#   (2,
#    0,
#    0,
#    0.020833333333333332,
#    "event headline:New Year's Eve grocery store hours: When Publix, Wegmans, Costco, Safeway, Whole Foods are open Friday; event type:MAKE STATEMENT; event time:2022-01-01; subject name:COMPANY; object name:UNITED STATES."),
#   (0,
#    11,
#    0,
#    0.020833333333333332,
#    'event headline:2 Killed When Train Hits Car Going Around Crossing Gate; event type:MAKE STATEMENT; event time:2022-01-01; subject name:UNITED STATES; object name:TELEVISION.'),
#   (10,
#    330,
#    3,
#    0.020833333333333332,
#    'event headline:Military preparing for promised consultations with sexual misconduct victims; event type:CONSULT; event time:2022-01-01; subject name:OTTAWA; object name:CANADIAN.'),
#   (8,
#    1,
#    11,
#    0.020833333333333332,
#    'event headline:alpek polyester s a v polymetrix ag fed 9928882; event type:REJECT; event time:2022-01-01; subject name:DISTRICT COURT; object name:MONARCH.'),
#   (25,
#    9,
#    3,
#    0.020833333333333332,
#    'event headline:US and Russia face deep differences ahead of Ukraine talks; event type:CONSULT; event time:2022-01-01; subject name:EUROPE; object name:UKRAINE.'),
#   (143,
#    7,
#    0,
#    0.020833333333333332,
#    'event headline:Interview: RCEP to catalyze sustainable economic recovery amid COVID-19, says ASEAN secretary-general; event type:MAKE STATEMENT; event time:2022-01-01; subject name:ASEAN; object name:CHINA.'),
#   (5,
#    0,
#    1,
#    0.020833333333333332,
#    'event headline:2021 brought closure to high-profile Central Florida court cases; event type:APPEAL; event time:2022-01-01; subject name:PRISON; object name:UNITED STATES.'),
#   (5,
#    0,
#    0,
#    0.020833333333333332,
#    'event headline:Fatal shooting: Paterson lags behind rest of state in equipping officers with body cameras; event type:MAKE STATEMENT; event time:2022-01-01; subject name:POLICE CHIEF; object name:UNITED STATES.'),
#   (3,
#    59,
#    16,
#    0.020833333333333332,
#    'event headline:News business sees low ratings without divisive politics of 2020; event type:COERCE; event time:2022-01-01; subject name:MOSCOW; object name:GOOGLE.'),
#   (2,
#    4,
#    6,
#    0.020833333333333332,
#    'event headline:How donating your unwanted items can sometimes do more harm than good; event type:PROVIDE AID; event time:2022-01-01; subject name:BANK; object name:COMMUNITY.'),
#   (89,
#    0,
#    0,
#    0.020833333333333332,
#    "event headline:GARY HOLT On EXODUS: We 'Love Each Other And Get Along' Despite Different Political Ideologies; event type:MAKE STATEMENT; event time:2022-01-01; subject name:AUSTRALIA; object name:UNITED STATES."),
#   (827,
#    7,
#    0,
#    0.020833333333333332,
#    'event headline:How To Report Your Positive At-Home COVID-19 Test Result; event type:MAKE STATEMENT; event time:2022-01-01; subject name:CANTON; object name:CANTON.'),
#   (196,
#    11,
#    12,
#    0.020833333333333332,
#    "event headline:New Year's Eve muted by Omicron fears; event type:THREATEN; event time:2022-01-01; subject name:SEOUL; object name:TELEVISION."),
#   (27,
#    12,
#    1,
#    0.020833333333333332,
#    'event headline:Winnie the Pooh and Tigger, too? Disney risks losing copyright protection on some characters; event type:APPEAL; event time:2022-01-01; subject name:DISNEY; object name:CONGRESS.'),
#   (47,
#    134,
#    2,
#    0.020833333333333332,
#    'event headline:MSC Cruise Ship Issues Additional Testing for Guests, Itinerary Adjusted; event type:EXPRESS INTENT TO COOPERATE; event time:2022-01-01; subject name:CARTAGENA; object name:COLOMBIA.'),
#   (16,
#    1,
#    3,
#    0.020833333333333332,
#    'event headline:Tony Blair to be given most senior knighthood in new year honours list; event type:CONSULT; event time:2022-01-01; subject name:FRANCE; object name:KING.'),
#   (0,
#    8,
#    0,
#    0.020833333333333332,
#    'event headline:Forced out of apartment weeks ago, now living in motel; event type:MAKE STATEMENT; event time:2022-01-01; subject name:UNITED STATES; object name:JUDGE.'),
#   (2,
#    37,
#    18,
#    0.020833333333333332,
#    'event headline:Over 65 shots fired on busy Philadelphia street; 6 wounded; event type:FIGHT; event time:2022-01-01; subject name:BUSINESS; object name:PHILADELPHIA.'),
#   (2,
#    32,
#    4,
#    0.020833333333333332,
#    'event headline:Betty White dies at 99: Here are some of her greatest career moments; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:BUSINESS; object name:ACTOR.'),
#   (14,
#    1,
#    3,
#    0.020833333333333332,
#    'event headline:Losing Shona and learning to live without him; event type:CONSULT; event time:2022-01-01; subject name:AFRICA; object name:KING.'),
#   (164,
#    26,
#    4,
#    0.041666666666666664,
#    'event headline:Pope Francis on New Year__ Eve: Jesus Christ gives meaning to our lives in joy and sorrow; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:VATICAN; object name:ITALY.'),
#   (29,
#    100,
#    14,
#    0.041666666666666664,
#    "event headline:Turkey's defense minister inspects troops along Syrian border; event type:EXHIBIT MILITARY POSTURE; event time:2022-01-01; subject name:TURKEY; object name:SYRIAN."),
#   (16,
#    91,
#    0,
#    0.041666666666666664,
#    "event headline:Omicron's New Year's cocktail: Sorrow, fear, hope for 2022; event type:MAKE STATEMENT; event time:2022-01-01; subject name:FRENCH; object name:FRANCE."),
#   (22,
#    0,
#    0,
#    0.041666666666666664,
#    'event headline:COVID forces changes to Nashville New Year s; event type:MAKE STATEMENT; event time:2022-01-01; subject name:UNITED STATES; object name:UNITED STATES.'),
#   (156,
#    5,
#    18,
#    0.041666666666666664,
#    'event headline:Man shot in the hand during car chase with police; event type:FIGHT; event time:2022-01-01; subject name:BAHAMA; object name:POLICE.'),
#   (18,
#    0,
#    0,
#    0.041666666666666664,
#    'event headline:Americans Won’t Be Cowed by Covid-19 – American Free Press; event type:MAKE STATEMENT; event time:2022-01-01; subject name:FRANKFORT; object name:KENTUCKY.'),
#   (7,
#    44,
#    0,
#    0.041666666666666664,
#    'event headline:Chinese bishops reportedly met with Hong Kong clerics on sinicization; event type:MAKE STATEMENT; event time:2022-01-01; subject name:CHINA; object name:RELIGION.'),
#   (32,
#    1,
#    0,
#    0.041666666666666664,
#    'event headline:Ending SPLC__ Reign of Terror: Christian Ministry Sues National Hatemonger _ American Free Press; event type:MAKE STATEMENT; event time:2022-01-01; subject name:FIRST LADY; object name:PRESIDENT.'),
#   (53,
#    6,
#    0,
#    0.041666666666666664,
#    'event headline:UAE: 33,792 Covid vaccine doses administered in 24 hours; event type:MAKE STATEMENT; event time:2022-01-01; subject name:ABU DHABI; object name:SCHOOL.'),
#   (4,
#    382,
#    3,
#    0.041666666666666664,
#    "event headline:Lincolnshire's Bernie Taupin CBE honour after more than 50 years making music with Elton John; event type:CONSULT; event time:2022-01-01; subject name:RESIDENTS; object name:ROLLS ROYCE."),
#   (1,
#    120,
#    0,
#    0.041666666666666664,
#    "event headline:Vermont outlines new 'test out' strategy for 5-day isolation and quarantine; event type:MAKE STATEMENT; event time:2022-01-01; subject name:PRESIDENT; object name:AMERICAN."),
#   (1,
#    8,
#    1,
#    0.041666666666666664,
#    'event headline:Gableman subpoenas election officials and city IT departments as GOP election review widens; event type:APPEAL; event time:2022-01-01; subject name:MAYOR; object name:JUDGE.'),
#   (0,
#    2,
#    2,
#    0.041666666666666664,
#    'event headline:SB 1383: What is it and what does it mean for San Diego businesses?; event type:EXPRESS INTENT TO COOPERATE; event time:2022-01-01; subject name:SAN DIEGO; object name:BUSINESS.'),
#   (80,
#    65,
#    0,
#    0.041666666666666664,
#    'event headline:nl biologist says avian flu in st johns very concerning for birds not humans 4913957; event type:MAKE STATEMENT; event time:2022-01-01; subject name:UNIVERSITY; object name:NORTH AMERICA.'),
#   (439,
#    17,
#    0,
#    0.041666666666666664,
#    'event headline:More provinces reduce COVID-19 isolation requirements as cases continue to mount; event type:MAKE STATEMENT; event time:2022-01-01; subject name:MANITOBA; object name:UNITED KINGDOM.'),
#   (0,
#    6,
#    1,
#    0.041666666666666664,
#    'event headline:MDHHS and MDE send letter to school superintendents; urges schools to take measures upon return from winter breaks; event type:APPEAL; event time:2022-01-01; subject name:MICHIGAN; object name:SCHOOL.'),
#   (21,
#    115,
#    5,
#    0.041666666666666664,
#    'event headline:Yes, you can catch COVID-19 multiple times; event type:ENGAGE IN MATERIAL COOPERATION; event time:2022-01-01; subject name:HOSPITAL; object name:OHIO.'),
#   (5,
#    28,
#    6,
#    0.041666666666666664,
#    'event headline:Sudanese Block Streets After Day of Protest Violence; event type:PROVIDE AID; event time:2022-01-01; subject name:POLICE; object name:SAUDI ARABIA.'),
#   (156,
#    0,
#    3,
#    0.041666666666666664,
#    'event headline:Cruise ship with COVID cases denied entry to Ocean Cay; event type:CONSULT; event time:2022-01-01; subject name:BAHAMA; object name:MIAMI.'),
#   (0,
#    2,
#    0,
#    0.041666666666666664,
#    'event headline:Best homeowners insurance in Delaware in 2022; event type:MAKE STATEMENT; event time:2022-01-01; subject name:DELAWARE; object name:COMPANIES.'),
#   (7,
#    52,
#    10,
#    0.041666666666666664,
#    'event headline:China protests near-collision with SpaceX satellite; event type:DISAPPROVE; event time:2022-01-01; subject name:CHINA; object name:THE UN.'),
#   (8,
#    12,
#    0,
#    0.041666666666666664,
#    'event headline:In a year-end report, Chief Justice John Roberts emphasizes judicial ethics; event type:MAKE STATEMENT; event time:2022-01-01; subject name:CHIEF JUSTICE; object name:CONGRESS.'),
#   (18,
#    7,
#    15,
#    0.041666666666666664,
#    'event headline:Will 2022 Bring A Revived Iran Nuclear Deal -- Or A Hard-Line Plan B?; event type:REDUCE RELATIONS; event time:2022-01-01; subject name:GERMANY; object name:CHINA.'),
#   (6,
#    40,
#    18,
#    0.041666666666666664,
#    'event headline:how extreme climate conditions fueled unprecedented colorado fire; event type:FIGHT; event time:2022-01-01; subject name:PROFESSOR; object name:MONTANA.'),
#   (26,
#    4,
#    4,
#    0.041666666666666664,
#    'event headline:Italian Prez thanks citizens for sense of responsibility in New Year speech; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:ITALIAN; object name:CITIZEN.'),
#   (0,
#    11,
#    0,
#    0.041666666666666664,
#    'event headline:Kushner__ Plan for Palestine Is a Gift for Longtime Friend _ American Free Press; event type:MAKE STATEMENT; event time:2022-01-01; subject name:UNITED STATES; object name:NEWS OUTLET.'),
#   (0,
#    11,
#    0,
#    0.041666666666666664,
#    'event headline:Family Calls Out Investigation Of Daughter, Lauren Smith-Fields, Who Died A___ter Meeting __lder White Man_ On Bumble; event type:MAKE STATEMENT; event time:2022-01-01; subject name:UNITED STATES; object name:TELEVISION.'),
#   (0,
#    22,
#    4,
#    0.041666666666666664,
#    'event headline:Tributes flow for legendary actress Betty White; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:UNITED STATES; object name:JOE BIDEN.'),
#   (8,
#    17,
#    0,
#    0.041666666666666664,
#    'event headline:Prince Andrew accuser seeks evidence of no sweating claim; event type:MAKE STATEMENT; event time:2022-01-01; subject name:LAWYER; object name:BRITISH.'),
#   (1354,
#    23,
#    4,
#    0.041666666666666664,
#    'event headline:What to expect in the Year of the Tiger; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:ZEN BUDDHISM; object name:JAPAN.'),
#   (6,
#    0,
#    3,
#    0.041666666666666664,
#    'event headline:Pointer: Cemetery restoration project a show of respect; event type:CONSULT; event time:2022-01-01; subject name:UNIVERSITY; object name:UNITED STATES.'),
#   (45,
#    1,
#    3,
#    0.041666666666666664,
#    'event headline:Should kids be vaccinated Brazil turns to online; event type:CONSULT; event time:2022-01-01; subject name:BRAZILIAN; object name:PRESIDENT.'),
#   (0,
#    1,
#    1,
#    0.041666666666666664,
#    'event headline:Virginia Guiffre__ lawyers ask for proof that Prince Andrew has a medical inability to sweat; event type:APPEAL; event time:2022-01-01; subject name:VIRGINIA; object name:PRINCE.'),
#   (291,
#    0,
#    6,
#    0.041666666666666664,
#    'event headline:FDIC chairman appointed by Trump resigns; event type:PROVIDE AID; event time:2022-01-01; subject name:SERBIA; object name:UNITED STATES.'),
#   (5,
#    0,
#    16,
#    0.041666666666666664,
#    'event headline:Bismarck police arrest woman wanted in Michigan; event type:COERCE; event time:2022-01-01; subject name:POLICE; object name:DETROIT.'),
#   (37,
#    5,
#    18,
#    0.041666666666666664,
#    'event headline:Police ID man who was fatally shot by police in; event type:FIGHT; event time:2022-01-01; subject name:MARYLAND; object name:POLICE.'),
#   (439,
#    10,
#    0,
#    0.041666666666666664,
#    'event headline:nl reports 431 new covid cases and one death walks back covid alert app comments 4912536; event type:MAKE STATEMENT; event time:2022-01-01; subject name:CANADA; object name:CANADA.'),
#   (38,
#    7,
#    1,
#    0.041666666666666664,
#    'event headline:Documents show Chinese government collects droves of data from Western social media: report; event type:APPEAL; event time:2022-01-01; subject name:CHINA; object name:CHINESE.'),
#   (1,
#    2,
#    6,
#    0.041666666666666664,
#    'event headline:__ don__ micromanage people_; event type:PROVIDE AID; event time:2022-01-01; subject name:GOVERNMENT; object name:INVESTOR.'),
#   (4,
#    0,
#    3,
#    0.041666666666666664,
#    'event headline:Who is the Largest Land Owner in Idaho?; event type:CONSULT; event time:2022-01-01; subject name:LANDOWNER; object name:MAINE.'),
#   (118,
#    0,
#    5,
#    0.041666666666666664,
#    'event headline:Qatar - Heavy snows hits Colorado after fires destroy hundre; event type:ENGAGE IN MATERIAL COOPERATION; event time:2022-01-01; subject name:QATAR; object name:COLORADO.'),
#   (302,
#    617,
#    4,
#    0.041666666666666664,
#    'event headline:Apel: Desmond Tutu - The rainbow man; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:NELSON MANDELA; object name:DESMOND TUTU.'),
#   (36,
#    36,
#    6,
#    0.041666666666666664,
#    'event headline:Wildfires burn hundreds of homes in Colorado, thousands flee; event type:PROVIDE AID; event time:2022-01-01; subject name:ASSOCIATED PRESS; object name:UNITED STATES.'),
#   (5,
#    0,
#    15,
#    0.041666666666666664,
#    'event headline:Marshall Fire burns hundreds of homes, forces thousands to evacuate in Boulder County; event type:REDUCE RELATIONS; event time:2022-01-01; subject name:POLICE; object name:LOUISVILLE.'),
#   (18,
#    34,
#    1,
#    0.041666666666666664,
#    'event headline:German Rosete aconseja a empresarios cautela en post pandemi; event type:APPEAL; event time:2022-01-01; subject name:GERMAN; object name:MEXICAN.'),
#   (0,
#    11,
#    0,
#    0.041666666666666664,
#    'event headline:Tennessee Planned Parenthood destroyed in early; event type:MAKE STATEMENT; event time:2022-01-01; subject name:MISSISSIPPI; object name:MEDIA.'),
#   (6,
#    152,
#    4,
#    0.041666666666666664,
#    'event headline:New Year celebrations held across China; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:STUDENT; object name:HOHHOT.'),
#   (5,
#    8,
#    0,
#    0.041666666666666664,
#    'event headline:Terrorizing Set of Behaviors Draws $50,000 Bond for Missoula Man; event type:MAKE STATEMENT; event time:2022-01-01; subject name:DEPUTY; object name:ATTORNEY.'),
#   (47,
#    1,
#    3,
#    0.0625,
#    'event headline:New Year s Eve muted by omicron many hoping for; event type:CONSULT; event time:2022-01-01; subject name:MADRID; object name:AUTHORITIES.'),
#   (3,
#    0,
#    12,
#    0.0625,
#    "event headline:You won't want to miss the 10 most popular 'Fresh Air' stories of 2021; event type:THREATEN; event time:2022-01-01; subject name:RUSSIA; object name:WASHINGTON."),
#   (5,
#    17,
#    16,
#    0.0625,
#    'event headline:Bradley Police murder suspect arrested in North Manchester; event type:COERCE; event time:2022-01-01; subject name:POLICE; object name:MANCHESTER.'),
#   (48,
#    25,
#    1,
#    0.0625,
#    'event headline:How Much Should NATO Spend on Defense?; event type:APPEAL; event time:2022-01-01; subject name:NATO; object name:EUROPE.'),
#   (15,
#    0,
#    18,
#    0.0625,
#    'event headline:Books 2021: In 1776, Seeing the Glimmer of Hope Against the Odds; event type:FIGHT; event time:2022-01-01; subject name:ARMY; object name:AMERICAN.'),
#   (0,
#    6,
#    6,
#    0.0625,
#    'event headline:Kentucky school districts devastated by tornadoes seek help; event type:PROVIDE AID; event time:2022-01-01; subject name:UNITED STATES; object name:SCHOOL.'),
#   (3,
#    4,
#    1,
#    0.0625,
#    'event headline:Nations enter 2022 with scaled-down celebrations as Omicron raises fear of abrupt infection surge; event type:APPEAL; event time:2022-01-01; subject name:RUSSIA; object name:POPULATION.'),
#   (5,
#    0,
#    6,
#    0.0625,
#    'event headline:Drug seizures increase in Ohio; event type:PROVIDE AID; event time:2022-01-01; subject name:LAW ENFORCEMENT AGENCIES; object name:UNITED STATES.'),
#   (0,
#    5,
#    18,
#    0.0625,
#    'event headline:Police Deputies serving warrant shot man armed; event type:FIGHT; event time:2022-01-01; subject name:SOUTH CAROLINA; object name:DEPUTIES.'),
#   (30,
#    15,
#    9,
#    0.0625,
#    'event headline:Five killed in protests against military rule in Sudan, doctors say; event type:DEMAND; event time:2022-01-01; subject name:DEMONSTRATOR; object name:MILITARY.'),
#   (5,
#    0,
#    18,
#    0.0625,
#    'event headline:2 people injured in shooting at Mall of America, police say; event type:FIGHT; event time:2022-01-01; subject name:POLICE; object name:UNITED STATES.'),
#   (1,
#    98,
#    1,
#    0.0625,
#    'event headline:US and Russia face deep differences ahead of Ukraine talks; event type:APPEAL; event time:2022-01-01; subject name:AMBASSADOR; object name:GEORGE W. BUSH.'),
#   (6,
#    4,
#    16,
#    0.0625,
#    'event headline:Brooks and Capehart on how American democracy fared in 2021, and their hopes for 2022; event type:COERCE; event time:2022-01-01; subject name:ACADEMICS; object name:VOTER.'),
#   (82,
#    6,
#    5,
#    0.0625,
#    'event headline:Books 2021: Rethinking the __arbarians_ by Critiquing Our Cultural Arrogance; event type:ENGAGE IN MATERIAL COOPERATION; event time:2022-01-01; subject name:ARGENTINA; object name:PROFESSOR.'),
#   (1,
#    0,
#    4,
#    0.0625,
#    'event headline:Walt Disney : Remembering Disney Legend Betty White; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:AMBASSADOR; object name:LOS ANGELES.'),
#   (7,
#    0,
#    10,
#    0.0625,
#    'event headline:Indonesia__ leadership of the G20; event type:DISAPPROVE; event time:2022-01-01; subject name:CHINA; object name:UNITED STATES.'),
#   (1,
#    21,
#    1,
#    0.0625,
#    'event headline:Appellate court refuses to make Elgin hospital give ivermectin to patient; event type:APPEAL; event time:2022-01-01; subject name:AUTHORITIES; object name:DOCTOR.'),
#   (26,
#    44,
#    3,
#    0.0625,
#    'event headline:; event type:CONSULT; event time:2022-01-01; subject name:NAPLES; object name:PREACHER.'),
#   (63,
#    3,
#    1,
#    0.0625,
#    'event headline:Biden talks sanctions, Putin warns of rupture over Ukraine; event type:APPEAL; event time:2022-01-01; subject name:SWITZERLAND; object name:RUSSIA.'),
#   (45,
#    2,
#    0,
#    0.0625,
#    'event headline:Should kids be vaccinated? Brazil turns to online survey; event type:MAKE STATEMENT; event time:2022-01-01; subject name:BRAZIL; object name:COMPANIES.'),
#   (7,
#    15,
#    3,
#    0.0625,
#    'event headline:Xi stresses strength arises from united efforts; event type:CONSULT; event time:2022-01-01; subject name:CHINESE; object name:MILITARY COMMISSION.'),
#   (15,
#    0,
#    10,
#    0.0625,
#    'event headline:__ Can Go Anywhere_: How Service Dogs Help Veterans With PTSD; event type:DISAPPROVE; event time:2022-01-01; subject name:AIRMAN; object name:UNITED STATES.'),
#   (7,
#    20,
#    0,
#    0.0625,
#    'event headline:Canton supervisor hopes updated policy aids employee retention; event type:MAKE STATEMENT; event time:2022-01-01; subject name:CANTON; object name:EMPLOYEE.'),
#   (3,
#    15,
#    7,
#    0.0625,
#    'event headline:One Soviet Sub Almost Started a War with Sweden; event type:YIELD; event time:2022-01-01; subject name:RUSSIA; object name:NAVAL BASE.'),
#   (10,
#    51,
#    6,
#    0.0625,
#    'event headline:Canada to resettle female Afghan judges, families living in limbo; event type:PROVIDE AID; event time:2022-01-01; subject name:CANADA; object name:AFGHAN.'),
#   (35,
#    3,
#    4,
#    0.0625,
#    'event headline:Israelis pack bars and restaurants to ring in New Year despite fresh restrictions; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:ISRAEL; object name:RUSSIA.'),
#   (11,
#    0,
#    3,
#    0.0625,
#    'event headline:Disaster Declared in Colorado After Fire That __elt Like the Apocalypse_; event type:CONSULT; event time:2022-01-01; subject name:TELEVISION; object name:UNITED STATES.'),
#   (1,
#    11,
#    0,
#    0.0625,
#    'event headline:Hollywood Pays Tribute to Betty White Our; event type:MAKE STATEMENT; event time:2022-01-01; subject name:PRESIDENT; object name:CORRESPONDENT.'),
#   (11,
#    0,
#    16,
#    0.0625,
#    'event headline:Betty White Dead at 99; event type:COERCE; event time:2022-01-01; subject name:TELEVISION; object name:UNITED STATES.'),
#   (0,
#    22,
#    16,
#    0.0625,
#    'event headline:Photos: Wildfires engulf 1,000 homes in suburban Denver; event type:COERCE; event time:2022-01-01; subject name:DENVER; object name:COLORADO.'),
#   (0,
#    5,
#    4,
#    0.08333333333333333,
#    'event headline:Flags flown at half-staff Friday to honor Itasca County deputy; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:MINNESOTA; object name:DEPUTY.'),
#   (36,
#    0,
#    6,
#    0.08333333333333333,
#    "event headline:__o Many Memories': Over 500 Homes Feared Destroyed by Fire; event type:PROVIDE AID; event time:2022-01-01; subject name:ASSOCIATED PRESS; object name:UNITED STATES."),
#   (99,
#    100,
#    7,
#    0.08333333333333333,
#    'event headline:SHOULD ARMENIA GRANT CITIZENSHIP TO FOREIGN INVESTORS?; event type:YIELD; event time:2022-01-01; subject name:ARMENIAN; object name:ALEPPO.'),
#   (331,
#    682,
#    3,
#    0.08333333333333333,
#    'event headline:HOW THE WEST EATS ITS CHILDREN; event type:CONSULT; event time:2022-01-01; subject name:ANGOLA; object name:BURUNDI.'),
#   (5,
#    8,
#    1,
#    0.08333333333333333,
#    'event headline:Tag: US Supreme Court _ NBC4 Washington; event type:APPEAL; event time:2022-01-01; subject name:POLICE; object name:ADVOCATE.'),
#   (4,
#    990,
#    18,
#    0.08333333333333333,
#    'event headline:KURDISH MEMBER OF TURKISH PARLIAMENT DELIVERS A HARSH SPEECH & ENDS UP IN JAIL; event type:FIGHT; event time:2022-01-01; subject name:CIVILIAN; object name:KURD.'),
#   (62,
#    15,
#    10,
#    0.08333333333333333,
#    'event headline:WHEN YOU WANT TO SANCTION STATES, YOU CALL THEM _«TERRORISTS_»; event type:DISAPPROVE; event time:2022-01-01; subject name:CHRISTIANITY; object name:MILITARY.'),
#   (0,
#    8,
#    0,
#    0.08333333333333333,
#    'event headline:A Look Back on Betty White and Her Love of Animals; event type:MAKE STATEMENT; event time:2022-01-01; subject name:LOS ANGELES; object name:ADVOCATE.'),
#   (6,
#    11,
#    3,
#    0.08333333333333333,
#    'event headline:Betty White, The Golden Girl From The Golden Days Of Television; event type:CONSULT; event time:2022-01-01; subject name:SCHOOL; object name:TELEVISION.'),
#   (17,
#    278,
#    8,
#    0.08333333333333333,
#    "event headline:Bad news for New Year's Eve revellers! Hangover 'cures' don't work, study says; event type:INVESTIGATE; event time:2022-01-01; subject name:LONDON; object name:UNITED KINGDOM."),
#   (362,
#    7,
#    3,
#    0.08333333333333333,
#    'event headline:india says china inventing names in disputed region; event type:CONSULT; event time:2022-01-01; subject name:TIBETAN; object name:CHINESE.'),
#   (7,
#    52,
#    11,
#    0.08333333333333333,
#    'event headline:eu backs international arms embargo after killings in myanmar; event type:REJECT; event time:2022-01-01; subject name:CHINA; object name:THE SECURITY COUNCIL.'),
#   (14,
#    10,
#    10,
#    0.08333333333333333,
#    'event headline:The impact of COVID-19 has been lower in Africa; event type:DISAPPROVE; event time:2022-01-01; subject name:AFRICA; object name:CANADA.'),
#   (7,
#    6,
#    3,
#    0.08333333333333333,
#    'event headline:CHINA EXPANDS RESEARCH FUNDING, LURING U; event type:CONSULT; event time:2022-01-01; subject name:TIANJIN; object name:UNIVERSITY.'),
#   (1,
#    3,
#    0,
#    0.08333333333333333,
#    'event headline:Putin reviews 2021 in longest-ever New Year address; event type:MAKE STATEMENT; event time:2022-01-01; subject name:PRESIDENT; object name:MOSCOW.'),
#   (0,
#    20,
#    1,
#    0.08333333333333333,
#    'event headline:Tesla Asks Employees to Fight Policy Proposal That Would Make Rooftop Solar More Expensive in California; event type:APPEAL; event time:2022-01-01; subject name:CALIFORNIA; object name:EMPLOYEE.'),
#   (18,
#    5,
#    1,
#    0.08333333333333333,
#    'event headline:New Year s Eve muted by omicron many hoping for; event type:APPEAL; event time:2022-01-01; subject name:BERLIN; object name:POLICE.'),
#   (1,
#    2,
#    1,
#    0.08333333333333333,
#    "event headline:Vancouver's plastic bag ban, fees for single-use cups start New Year's Day; event type:APPEAL; event time:2022-01-01; subject name:GOVERNMENT; object name:BUSINESS."),
#   (7,
#    74,
#    4,
#    0.08333333333333333,
#    'event headline:Unable to cross the border to China, farm produce is sold on pavements; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:CHINESE; object name:LANG SON.'),
#   (0,
#    5,
#    17,
#    0.08333333333333333,
#    'event headline:Mall of America shooting: 2 injured after altercation, mall secure after lockdown; event type:ASSAULT; event time:2022-01-01; subject name:UNITED STATES; object name:POLICE.'),
#   (5,
#    2,
#    0,
#    0.08333333333333333,
#    'event headline:Localization law for foreign Big Tech companies enters into force in Russia; event type:MAKE STATEMENT; event time:2022-01-01; subject name:DEPUTY; object name:COMPANIES.'),
#   (181,
#    0,
#    3,
#    0.08333333333333333,
#    "event headline:Orlando Bloom's ex Kate Bosworth finds love with Drew Barrymore's ex Justin Long; event type:CONSULT; event time:2022-01-01; subject name:ESTONIA; object name:UNITED STATES."),
#   (1,
#    3,
#    1,
#    0.08333333333333333,
#    'event headline:putin warns biden of complete breakdown in us russian relations; event type:APPEAL; event time:2022-01-01; subject name:PRESIDENT; object name:MOSCOW.'),
#   (13,
#    1,
#    4,
#    0.08333333333333333,
#    "event headline:Queen's Platinum Jubilee to be celebrated; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:AUSTRALIA; object name:MONARCH."),
#   (18,
#    35,
#    4,
#    0.08333333333333333,
#    'event headline:Germany pulls honor for Israeli historian over report on Srebrenica massacre; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:GERMANY; object name:ISRAELI.'),
#   (115,
#    3,
#    1,
#    0.08333333333333333,
#    'event headline:GENETICALLY ENGINEERED VIRUSES MAY BECOME THE NEXT GENERATION OF WARFARE; event type:APPEAL; event time:2022-01-01; subject name:THE US; object name:RUSSIAN.'),
#   (99,
#    64,
#    11,
#    0.08333333333333333,
#    'event headline:; event type:REJECT; event time:2022-01-01; subject name:ARMENIA; object name:UNITED STATES.'),
#   (7,
#    106,
#    2,
#    0.10416666666666667,
#    'event headline:Sri Lanka - Wang Yi to visit Sri Lanka from 8-9 January; event type:EXPRESS INTENT TO COOPERATE; event time:2022-01-01; subject name:CHINESE; object name:COLOMBO.'),
#   (172,
#    2,
#    1,
#    0.10416666666666667,
#    'event headline:County__ positive test rate more than triples in a week; event type:APPEAL; event time:2022-01-01; subject name:AIRLINE; object name:AIRLINE.'),
#   (10,
#    1,
#    10,
#    0.10416666666666667,
#    'event headline:Ontario to stop collecting COVID-19 numbers from school boards, suspend reporting of cases; event type:DISAPPROVE; event time:2022-01-01; subject name:CANADA; object name:PREMIER.'),
#   (5,
#    0,
#    18,
#    0.10416666666666667,
#    'event headline:police mall america shooting leaves people injured 82026182; event type:FIGHT; event time:2022-01-01; subject name:POLICE; object name:UNITED STATES.'),
#   (7,
#    6,
#    16,
#    0.10416666666666667,
#    "event headline:Hong Kong's statues are disappearing, but their symbolism may prove harder to erase; event type:COERCE; event time:2022-01-01; subject name:CHINESE; object name:UNIVERSITY."),
#   (10,
#    0,
#    1,
#    0.10416666666666667,
#    'event headline:Microbiologist urges small New Year__ Eve gatherings despite changing Omicron landscape; event type:APPEAL; event time:2022-01-01; subject name:ONTARIO; object name:UNITED STATES.'),
#   (77,
#    31,
#    15,
#    0.10416666666666667,
#    'event headline:US, South Korea Agree On Draft Declaration To End Korean War; event type:REDUCE RELATIONS; event time:2022-01-01; subject name:PYONGYANG; object name:SEOUL.'),
#   (7,
#    519,
#    4,
#    0.10416666666666667,
#    'event headline:China reopens its embassy in Nicaragua; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:CHINA; object name:NICARAGUA.'),
#   (0,
#    14,
#    8,
#    0.10416666666666667,
#    'event headline:Veronique de Rugy: Three books for liberty-loving readers in 2022; event type:INVESTIGATE; event time:2022-01-01; subject name:UNITED STATES; object name:AFRICA.'),
#   (4,
#    233,
#    3,
#    0.10416666666666667,
#    'event headline:Wellness Hub helps you cope with pandemic-related stress and anxiety; event type:CONSULT; event time:2022-01-01; subject name:RESIDENTS; object name:YOGA.'),
#   (459,
#    0,
#    18,
#    0.10416666666666667,
#    'event headline:Bringing out the Big Guns; event type:FIGHT; event time:2022-01-01; subject name:APACHE; object name:UNITED STATES.'),
#   (76,
#    0,
#    0,
#    0.10416666666666667,
#    'event headline:Betty White: 100 Years Young movie special WILL be released as planned as tribute to comedy legend; event type:MAKE STATEMENT; event time:2022-01-01; subject name:UNITED STATES; object name:UNITED STATES.'),
#   (0,
#    8,
#    1,
#    0.10416666666666667,
#    'event headline:The truth is our strongest weapon against the lies that fed the Jan; event type:APPEAL; event time:2022-01-01; subject name:UNITED STATES; object name:SUPREME COURT.'),
#   (5,
#    1,
#    2,
#    0.10416666666666667,
#    'event headline:Hate-Crime Hoaxes Of 2021; event type:EXPRESS INTENT TO COOPERATE; event time:2022-01-01; subject name:POLICE; object name:STATE ATTORNEY GENERAL.'),
#   (0,
#    5,
#    16,
#    0.10416666666666667,
#    'event headline:ISP announce additional suspect in custody in relation to shooting of Bradley Police Officers; event type:COERCE; event time:2022-01-01; subject name:ILLINOIS; object name:POLICE.'),
#   (0,
#    20,
#    0,
#    0.10416666666666667,
#    'event headline:The US Postal Service is getting hit by Omicron after it survived the holiday season by enlisting tens of thousands of workers; event type:MAKE STATEMENT; event time:2022-01-01; subject name:THE US; object name:WORKER.'),
#   (7,
#    4,
#    3,
#    0.10416666666666667,
#    'event headline:Photos at President Xi Jinping s 2022 New Year address; event type:CONSULT; event time:2022-01-01; subject name:CHINA; object name:VILLAGER.'),
#   (21,
#    0,
#    18,
#    0.10416666666666667,
#    "event headline:6-year-old with epilepsy battling COVID-19 at Phoenix Children's for two weeks; event type:FIGHT; event time:2022-01-01; subject name:HOSPITAL; object name:PHOENIX."),
#   (22,
#    22,
#    0,
#    0.10416666666666667,
#    'event headline:Federal judge rebuffs First Amendment argument from lawyers for Proud Boys in Jan; event type:MAKE STATEMENT; event time:2022-01-01; subject name:UNITED STATES; object name:THE WHITE HOUSE.'),
#   (0,
#    4,
#    16,
#    0.10416666666666667,
#    'event headline:What we know about the ‘devastating’ Colorado fires; event type:COERCE; event time:2022-01-01; subject name:DENVER; object name:RESIDENTS.'),
#   (6,
#    1,
#    3,
#    0.10416666666666667,
#    'event headline:School districts waiting for arrival of COVID test kits; event type:CONSULT; event time:2022-01-01; subject name:SCHOOL; object name:GOVERNOR.'),
#   (0,
#    22,
#    10,
#    0.10416666666666667,
#    'event headline:Has Prez Biden FAILED Kansas City Fight Against COVID?!?; event type:DISAPPROVE; event time:2022-01-01; subject name:KANSAS; object name:UNITED STATES.'),
#   (13,
#    0,
#    1,
#    0.10416666666666667,
#    'event headline:Their name was Pauli Murray; event type:APPEAL; event time:2022-01-01; subject name:MURRAY; object name:UNITED STATES.'),
#   (10,
#    496,
#    3,
#    0.10416666666666667,
#    'event headline:Longtime Kugluktuk leader Asger __ed_ Pedersen named to Order of Canada; event type:CONSULT; event time:2022-01-01; subject name:CANADA; object name:GREENLAND.'),
#   (17,
#    0,
#    1,
#    0.10416666666666667,
#    'event headline:SF in India by Shweta Taneja; event type:APPEAL; event time:2022-01-01; subject name:LONDON; object name:NEW YORK.'),
#   (16,
#    91,
#    3,
#    0.10416666666666667,
#    'event headline:Cody Garbrandt Not Ruling Out Flyweight, Wants Sean O__alley; event type:CONSULT; event time:2022-01-01; subject name:FRANCE; object name:FRANCE.'),
#   (44,
#    14,
#    0,
# ...
#   (30,
#    0,
#    3,
#    0.7708333333333334,
#    'event headline:FISA Abuse Memo Is the __moking Gun_ of Corruption, __atergate Is Child__ Play_; event type:CONSULT; event time:2022-01-01; subject name:THE OPPOSITION; object name:WASHINGTON.'),
#   (36,
#    41,
#    10,
#    0.7708333333333334,
#    'event headline:Iran Space Launch Fails to Put Payloads Into Orbit; event type:DISAPPROVE; event time:2022-01-01; subject name:REUTERS; object name:TEHRAN.'),
#   (41,
#    523,
#    18,
#    0.7708333333333334,
#    'event headline:Russian Warplanes Hit Areas in Northwest Syria; event type:FIGHT; event time:2022-01-01; subject name:IRANIAN; object name:SHIITE.'),
#   (12,
#    95,
#    16,
#    0.7708333333333334,
#    'event headline:Will submit replies to court, YSRCP rebel MP on CBI charge sheet; event type:COERCE; event time:2022-01-01; subject name:CONGRESS; object name:REBEL.'),
#   (199,
#    29,
#    4,
#    0.7708333333333334,
#    'event headline:Turkey: Holding Elections Most Important Way Ensure Libya__ Unity; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:TRIPOLI; object name:ANKARA.'),
#   (26,
#    5,
#    12,
#    0.7708333333333334,
#    'event headline:Ranjith Sreenivasan murder case: Kerala police unable to make headway; event type:THREATEN; event time:2022-01-01; subject name:MARCHE; object name:POLICE.'),
#   (12,
#    1,
#    8,
#    0.7708333333333334,
#    'event headline:Parliamentary Committee on Home Affairs visit to Hyderabad, Goa postponed; event type:INVESTIGATE; event time:2022-01-01; subject name:SPEAKER OF THE HOUSE; object name:MINIST.'),
#   (143,
#    7,
#    0,
#    0.7708333333333334,
#    'event headline:Interview: RCEP to catalyze sustainable economic recovery amid COVID-19, says ASEAN secretary-general; event type:MAKE STATEMENT; event time:2022-01-01; subject name:ASEAN; object name:CHINA.'),
#   (7,
#    2,
#    5,
#    0.7708333333333334,
#    'event headline:People__ Daily__ top 10 domestic news events in 2021; event type:ENGAGE IN MATERIAL COOPERATION; event time:2022-01-01; subject name:SHENZHEN; object name:INDUSTRY.'),
#   (7,
#    38,
#    3,
#    0.7708333333333334,
#    'event headline:China shows __oncern_ over Indian parliamentarians meeting with Tibetan MPs; event type:CONSULT; event time:2022-01-01; subject name:CHINESE; object name:CHINESE.'),
#   (7,
#    0,
#    0,
#    0.7708333333333334,
#    'event headline:Asian-American groups call for end of controversial "China Initiative": CNBC; event type:MAKE STATEMENT; event time:2022-01-01; subject name:CHINA; object name:AMERICAN.'),
#   (2,
#    0,
#    3,
#    0.7708333333333334,
#    'event headline:in-focus-t-s-eliots-journey-of-the-magi-the-masterpiece-that-was-dashed-off-in-45-minutes; event type:CONSULT; event time:2022-01-01; subject name:BANK; object name:UNITED STATES.'),
#   (28,
#    54,
#    3,
#    0.7708333333333334,
#    'event headline:Are Sandakan umrah cluster cases Omicron? Testing still underway, says official; event type:CONSULT; event time:2022-01-01; subject name:SAUDI ARABIA; object name:HEALTH MINIST.'),
#   (4,
#    6,
#    3,
#    0.7708333333333334,
#    'event headline:Eco warriors of UoH, PU join hands for Puducherry beach clean-up drive; event type:CONSULT; event time:2022-01-01; subject name:TOURIST; object name:SCHOLAR.'),
#   (143,
#    7,
#    4,
#    0.7708333333333334,
#    "event headline:World's largest free trade deal takes effect on first day of 2022; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:ASSOCIATION OF SOUTHEAST ASIAN NATIONS; object name:CHINA."),
#   (1,
#    1051,
#    6,
#    0.7916666666666666,
#    'event headline:Raising legal age for marriage for women in India: Here__ why it__ bad news for women; event type:PROVIDE AID; event time:2022-01-01; subject name:GOVERNMENT; object name:BETI.'),
#   (1,
#    708,
#    5,
#    0.7916666666666666,
#    'event headline:preface and introduction; event type:ENGAGE IN MATERIAL COOPERATION; event time:2022-01-01; subject name:GOVERNMENT; object name:FIDEL CASTRO.'),
#   (6,
#    0,
#    3,
#    0.7916666666666666,
#    'event headline:UC Berkeley__ Haas School of Business, Google Challenge Students To Develop Business Strategies for Mental Healthcare; event type:CONSULT; event time:2022-01-01; subject name:STUDENT; object name:UNITED STATES.'),
#   (2,
#    0,
#    10,
#    0.7916666666666666,
#    'event headline:Health and wellness centre opens at New York JFK _ Business Traveller; event type:DISAPPROVE; event time:2022-01-01; subject name:COMPANY; object name:NEW YORK.'),
#   (30,
#    50,
#    7,
#    0.7916666666666666,
#    'event headline:Pakistan, India exchange lists of prisoners; event type:YIELD; event time:2022-01-01; subject name:PRISONER; object name:PAKISTAN.'),
#   (30,
#    50,
#    7,
#    0.7916666666666666,
#    "event headline:Pakistan, India exchange details of prisoners in each other's custody, nuclear facilities; event type:YIELD; event time:2022-01-01; subject name:PRISONER; object name:PAKISTAN."),
#   (0,
#    2,
#    0,
#    0.7916666666666666,
#    'event headline:MarketBeat: Stock Market News and Research Tools; event type:MAKE STATEMENT; event time:2022-01-01; subject name:AMERICAN; object name:SECURITIES EXCHANGE.'),
#   (51,
#    8,
#    4,
#    0.7916666666666666,
#    'event headline:Rubin: As US tightens visa rules, Afghan allies get left behind; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:AFGHAN; object name:JUDGE.'),
#   (11,
#    41,
#    18,
#    0.7916666666666666,
#    'event headline:Iran State TV Says Tehran Launched Rocket Into Space: AP; event type:FIGHT; event time:2022-01-01; subject name:TELEVISION; object name:IRANIAN.'),
#   (4,
#    0,
#    3,
#    0.7916666666666666,
#    'event headline:MarketBeat: Stock Market News and Research Tools; event type:CONSULT; event time:2022-01-01; subject name:VILLAGE; object name:UNITED STATES.'),
#   (2,
#    24,
#    6,
#    0.7916666666666666,
#    'event headline:MarketBeat: Stock Market News and Research Tools; event type:PROVIDE AID; event time:2022-01-01; subject name:BUSINESS; object name:DEALER.'),
#   (39,
#    3,
#    3,
#    0.7916666666666666,
#    'event headline:Abbas warns Putin over Israel__ economic and security steps _ Famagusta Gazette; event type:CONSULT; event time:2022-01-01; subject name:EUROPEAN UNION; object name:RUSSIA.'),
#   (7,
#    38,
#    0,
#    0.7916666666666666,
#    "event headline:Xi Focus: Xi addresses 2022 New Year gathering of China's top political advisory body; event type:MAKE STATEMENT; event time:2022-01-01; subject name:BEIJING; object name:XI JINPING."),
#   (2,
#    1,
#    0,
#    0.7916666666666666,
#    'event headline:Apple Faces CCI Antitrust Probe Over Alleged Abuse of App Market; event type:MAKE STATEMENT; event time:2022-01-01; subject name:COMPANY; object name:REGULATOR.'),
#   (7,
#    1,
#    11,
#    0.7916666666666666,
#    'event headline:China welcomes 2022 with the worst week of COVID-19 dominating the virus; event type:REJECT; event time:2022-01-01; subject name:XIAN; object name:AUTHORITIES.'),
#   (15,
#    7,
#    11,
#    0.7916666666666666,
#    'event headline:why-us-military-will-never-invade-china; event type:REJECT; event time:2022-01-01; subject name:ARMY; object name:CHINA.'),
#   (61,
#    7,
#    1,
#    0.8125,
#    'event headline:Taiwan leader urges China to curb military; event type:APPEAL; event time:2022-01-01; subject name:TAIWAN; object name:CHINA.'),
#   (13,
#    2,
#    4,
#    0.8125,
#    "event headline:Queensland cleaning company deliver perfect comeback to a 'racist' customer on Facebook; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:QUEENSLAND; object name:BUSINESS."),
#   (6,
#    152,
#    4,
#    0.8125,
#    'event headline:New Year celebrations held across China; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:STUDENT; object name:HEFEI.'),
#   (47,
#    26,
#    2,
#    0.8125,
#    'event headline:Transfer News: Inter Milan battle Barcelona for Hakim Ziyech; event type:EXPRESS INTENT TO COOPERATE; event time:2022-01-01; subject name:BARCELONA; object name:MILAN.'),
#   (1,
#    7,
#    6,
#    0.8125,
#    'event headline:Pakistan: 70 Million Fully Vaccinated Against COVID-19; event type:PROVIDE AID; event time:2022-01-01; subject name:GOVERNMENT; object name:CHINA.'),
#   (16,
#    35,
#    10,
#    0.8125,
#    'event headline:CIA, Mossad Suspected in Cyberattack _ American Free Press; event type:DISAPPROVE; event time:2022-01-01; subject name:FRENCH; object name:ISRAEL.'),
#   (1553,
#    8,
#    0,
#    0.8125,
#    'event headline:Bishop Finn found guilty; convicted of one misdemeanor count; event type:MAKE STATEMENT; event time:2022-01-01; subject name:FINN; object name:JUDGE.'),
#   (4,
#    1,
#    2,
#    0.8125,
#    'event headline:Barangay San Antonio seniors get cash gifts; event type:EXPRESS INTENT TO COOPERATE; event time:2022-01-01; subject name:RESIDENTS; object name:GOVERNMENT.'),
#   (5,
#    13,
#    18,
#    0.8125,
#    "event headline:Perth pub locked down after cops find 300 New Year's Eve revellers partying in breach of Covid rules; event type:FIGHT; event time:2022-01-01; subject name:POLICE; object name:PERTH."),
#   (22,
#    25,
#    0,
#    0.8125,
#    'event headline:The International Space Station just had its lease on life extended; event type:MAKE STATEMENT; event time:2022-01-01; subject name:NASA; object name:EUROPE.'),
#   (64,
#    0,
#    4,
#    0.8125,
#    'event headline:Locals rage as neighbour sends them cards telling them to shut up at 10pm on NYE; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:HOUSTON; object name:TEXAS.'),
#   (400,
#    4,
#    18,
#    0.8125,
#    'event headline:49 civilians among 350 killed in Kashmir in 2021, claims pro-freedom alliance; event type:FIGHT; event time:2022-01-01; subject name:KASHMIRI; object name:CIVILIAN.'),
#   (51,
#    1,
#    2,
#    0.8125,
#    'event headline:India dispatches next batch of humanitarian aid to Afghanistan; event type:EXPRESS INTENT TO COOPERATE; event time:2022-01-01; subject name:AFGHANISTAN; object name:EXTERNAL AFFAIRS MINIST.'),
#   (0,
#    140,
#    4,
#    0.8125,
#    'event headline:Former Delta boss urges US must lift sanctions on Zimbabwe to propel the country forward; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:UNITED STATES; object name:ZIMBABWE.'),
#   (16,
#    94,
#    10,
#    0.8125,
#    'event headline:Iran Space Launch Fails to Put Payloads Into Orbit; event type:DISAPPROVE; event time:2022-01-01; subject name:PARIS; object name:VIENNA.'),
#   (51,
#    48,
#    9,
#    0.8333333333333334,
#    'event headline:The world must not look away as the Taliban sexually enslave; event type:DEMAND; event time:2022-01-01; subject name:AFGHANISTAN; object name:NATO.'),
#   (236,
#    133,
#    15,
#    0.8333333333333334,
#    'event headline:Afghanistan - Russia wants Taliban to keep promises for reco; event type:REDUCE RELATIONS; event time:2022-01-01; subject name:THE UN; object name:TALIBAN.'),
#   (5,
#    19,
#    17,
#    0.8333333333333334,
#    'event headline:12 dead in stampede in India-controlled Kashmir; event type:ASSAULT; event time:2022-01-01; subject name:POLICEMAN; object name:NEW DELHI.'),
#   (5,
#    1,
#    10,
#    0.8333333333333334,
#    'event headline:neet-pg-counselling-delay-maharashtra-resident-doctors-to-continue-strike-despite-forda-calling-it-off; event type:DISAPPROVE; event time:2022-01-01; subject name:POLICE; object name:MINISTRY.'),
#   (1,
#    36,
#    0,
#    0.8333333333333334,
#    'event headline:Afghanistan - Canada to resettle female Afghan judges, famil; event type:MAKE STATEMENT; event time:2022-01-01; subject name:IMMIGRATION MINIST; object name:REUTERS.'),
#   (2,
#    0,
#    3,
#    0.8333333333333334,
#    'event headline:Uranium Energy Corp completes acquisition of Uranium One Americas; largest uranium mining company in US; event type:CONSULT; event time:2022-01-01; subject name:COMPANY; object name:WYOMING.'),
#   (1,
#    4,
#    7,
#    0.8333333333333334,
#    'event headline:Will 628 Indians imprisoned in Pakistan be able to return? India submits list to PAK; event type:YIELD; event time:2022-01-01; subject name:MINIST OF FOREIGN AFFAIRS; object name:CITIZEN.'),
#   (7,
#    519,
#    4,
#    0.8333333333333334,
#    'event headline:China reopens embassy in Nicaragua; event type:ENGAGE IN DIPLOMATIC COOPERATION; event time:2022-01-01; subject name:CHINA; object name:NICARAGUA.'),
#   (39,
#    402,
#    12,
#    0.8333333333333334,
#    'event headline:Orient Express returns to Italy after nearly 50 years; event type:THREATEN; event time:2022-01-01; subject name:THE EU; object name:BRITISH.'),
#   (58,
#    210,
#    11,
#    0.8333333333333334,
#    "event headline:Journalists: Attack was year's top religious event; event type:REJECT; event time:2022-01-01; subject name:CHRISTIAN CLERGY; object name:PROTESTANT."),
#   (13,
#    17,
#    3,
#    0.8333333333333334,
#    'event headline:Grim and grisly history of pub many of you have driven past; event type:CONSULT; event time:2022-01-01; subject name:AUSTRALIA; object name:UNITED KINGDOM.'),
#   (7,
#    61,
#    0,
#    0.8333333333333334,
#    "event headline:In New Year's speech, Taiwan president warns China against 'military adventurism'; event type:MAKE STATEMENT; event time:2022-01-01; subject name:CHINESE; object name:TAIWAN."),
#   (14,
#    17,
#    3,
#    0.8333333333333334,
#    'event headline:desmond-tutu-a-champion-of-faith-and-justice-andre-debattista; event type:CONSULT; event time:2022-01-01; subject name:AFRICA; object name:LONDON.'),
#   (1,
#    7,
#    1,
#    0.8333333333333334,
#    'event headline:Skillful training, fulfilling jobs, better lives -- Pakistanis feel CPEC benefits; event type:APPEAL; event time:2022-01-01; subject name:EMBASSY; object name:CHINA.'),
#   (0,
#    20,
#    10,
#    0.8333333333333334,
#    'event headline:tesla-ceo-elon-musk-advices-young-people-to-learn-as-much-as-possible; event type:DISAPPROVE; event time:2022-01-01; subject name:UNITED STATES; object name:EMPLOYEE.'),
#   (36,
#    0,
#    6,
#    0.8333333333333334,
#    'event headline:Officials: Nearly 1K structures destroyed in Colorado fire; event type:PROVIDE AID; event time:2022-01-01; subject name:ASSOCIATED PRESS; object name:SALT LAKE CITY.'),
#   (0,
#    115,
#    6,
#    0.8333333333333334,
#    'event headline:Kentucky Colonels Make Huge Tornado Relief Donation; event type:PROVIDE AID; event time:2022-01-01; subject name:KENTUCKY; object name:UNITED STATES.'),
#   (18,
#    1,
#    7,
#    0.8333333333333334,
#    'event headline:The EU needs leadership in 2022; event type:YIELD; event time:2022-01-01; subject name:GERMAN; object name:GOVERNMENT.'),
#   (29,
#    2170,
#    16,
#    0.8333333333333334,
#    'event headline:Buhari to IGP: Use INTERPOL to Confront Our Challenges; event type:COERCE; event time:2022-01-01; subject name:ISTANBUL; object name:INTERPOL.'),
#   (14,
#    44,
#    0,
#    0.8541666666666666,
#    'event headline:desmond tutu funeral naomi tutushares emotional tribute to her father; event type:MAKE STATEMENT; event time:2022-01-01; subject name:AFRICA; object name:ARCHBISHOP.'),
#   (0,
#    115,
#    3,
#    0.8541666666666666,
#    'event headline:Hollywood__ Golden Girl: Betty White dies, weeks shy of 100th birthday; event type:CONSULT; event time:2022-01-01; subject name:A US; object name:A US.'),
#   (14,
#    44,
#    0,
#    0.8541666666666666,
#    'event headline:live blog archbishop desmond tutus funeral emotional tributes pour out for anti apartheid icon; event type:MAKE STATEMENT; event time:2022-01-01; subject name:AFRICA; object name:ARCHBISHOP.'),
#   (10,
#    416,
#    3,
#    0.8541666666666666,
#    'event headline:AstraZeneca second dose: Should I get the same vaccine or ch; event type:CONSULT; event time:2022-01-01; subject name:CANADA; object name:ASTRAZENECA.'),
#   (1366,
#    11,
#    13,
#    0.8541666666666666,
#    'event headline:OPINION | MASTERSON ONLINE: Chats with Benji; event type:PROTEST; event time:2022-01-01; subject name:HUNGARY; object name:WEBSITE.'),
#   (6,
#    0,
#    2,
#    0.8541666666666666,
#    'event headline:Love in the Big City Summary & Study Guide; event type:EXPRESS INTENT TO COOPERATE; event time:2022-01-01; subject name:STUDENT; object name:NEW YORK.'),
#   ...]}

# %%
(72,26,3,0.0,'event headline:Biden to Speak with Zelenskiy, Says He Warned Putin on Ukraine; event type:CONSULT; event time:2022-01-01; subject name:CANADA; object name:ITALY.')
